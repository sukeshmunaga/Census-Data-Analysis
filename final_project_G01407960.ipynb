# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea

# %%
data_frame=pd.read_csv(r"C:\Users\chara\Desktop\AIT 580\final project\Project_G01407960.csv")

# %%
data_frame.head(5)
# Out:
#    Age         Work Class  Final_weight   Education  Education_num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  Native_country   Class  income
# ...

# %%
data_frame.dtypes
# Out:
# Age                int64
# Work Class        object
# Final_weight       int64
# Education         object
# Education_num      int64
# marital status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# Native_country    object
# Class             object
# dtype: object

# %%
#RE1
sea.countplot(x="Class", data=data_frame)
plot.title("Distribution of Income")
plot.show()

# %%
sea.countplot(x="Class", hue="Sex", data=data_frame)
plot.title("Distribution of Income by sex")
plot.show()

# %%
high_income = data_frame[data_frame["Class"] == ">50K"]
low_income = data_frame[data_frame["Class"] == "<=50K"]

for column in ["Age", "Education_num", "hours_per_week"]:
    fig, ax = plot.subplots()
    sea.boxplot(x="Class", y=column, hue="Sex", data=data_frame, ax=ax)
    ax.set_title(column)

# %%
#RE2

# %%
fig, ax = plot.subplots(figsize=(10, 5))
sea.countplot(x="Education", hue="Class", data=data_frame)
plot.title("Distribution of education by Income level")
plot.xticks(rotation=90)
plot.show()

# %%
fig, ax = plot.subplots(figsize=(10, 5))
sea.countplot(x="Education", hue="Race", data=data_frame,)
plot.title("Distribution of education by Race")
plot.xticks(rotation=90)
plot.show()

# %%
#RE3

# %%
plot.figure(figsize=(8,4))
sea.countplot(x="Work Class", hue="Class", data=data_frame,)
plot.xticks(rotation=90)
plot.title("Distribution of Income by Workclass")
plot.show()

# %%
plot.figure(figsize=(12, 6))
sea.countplot(x="Occupation", hue="Class", data=data_frame)
plot.xticks(rotation=90)
plot.title("Distribution of Income by Occupation")
plot.show()
